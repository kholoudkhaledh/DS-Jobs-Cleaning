# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('DataScientist.csv')
data.head()
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
# ...

# %%
pd.set_option('display.max_columns',17)
pd.set_option('display.max_rows',3909)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3909 non-null   int64
#  1   index              3909 non-null   int64
#  2   Job Title          3909 non-null   object
#  3   Salary Estimate    3909 non-null   object
#  4   Job Description    3909 non-null   object
#  5   Rating             3909 non-null   float64
#  6   Company Name       3909 non-null   object
#  7   Location           3909 non-null   object
#  8   Headquarters       3909 non-null   object
#  9   Size               3909 non-null   object
#  10  Founded            3909 non-null   int64
#  11  Type of ownership  3909 non-null   object
#  12  Industry           3909 non-null   object
#  13  Sector             3909 non-null   object
#  14  Revenue            3909 non-null   object
#  15  Competitors        3909 non-null   object
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0        index       Rating      Founded
# count  3909.000000  3909.000000  3909.000000  3909.000000
# mean   1954.000000  2167.446662     3.283576  1479.154771
# std    1128.575429  1247.657849     1.575749   855.750138
# min       0.000000     0.000000    -1.000000    -1.000000
# 25%     977.000000  1121.000000     3.200000  1625.000000
# 50%    1954.000000  2161.000000     3.700000  1976.000000
# 75%    2931.000000  3249.000000     4.100000  2002.000000
# max    3908.000000  4379.000000     5.000000  2020.000000

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Unnamed: 0           0
# index                0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df = data.drop(['Unnamed: 0','index'],axis=1)
df.head()
# Out:
#                            Job Title               Salary Estimate  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
#                       Company Name       Location      Headquarters  \
# 0                      Hopper\n3.5   New York, NY  Montreal, Canada
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Data Scientist                                                                                                                                       274
# Data Engineer                                                                                                                                        260
# Data Analyst                                                                                                                                         246
# Senior Data Scientist                                                                                                                                 91
# Senior Data Analyst                                                                                                                                   47
# Machine Learning Engineer                                                                                                                             47
# ...

# %%
print(df['Job Title'].unique())
# Out:
# ['Senior Data Scientist' 'Data Scientist, Product Analytics'
#  'Data Science Manager' ... 'Cyber Security Data Engineer'
#  'Security Analytics Data Engineer'
#  'Patient Safety Physician or Safety Scientist - UK, Europe or the US']

# %%
df["Job Title"] = df['Job Title'].str.replace('Sr.', 'Senior')
df["Job Title"] = df['Job Title'].str.replace('Sr', 'Senior')
df["Job Title"] = df['Job Title'].str.replace('Jr', 'Junior')

# %%
df['Job Title']=df['Job Title'].apply(lambda x:x.join(x.split(',')[:1]))
df['Job Title']=df['Job Title'].apply(lambda x:x.join(x.split('/')[:1]))
df['Job Title']=df['Job Title'].apply(lambda x:x.join(x.split('-')[:1]))

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Data Scientist                                                                               357
# Data Engineer                                                                                290
# Data Analyst                                                                                 278
# Senior Data Scientist                                                                        144
# Data Scientist                                                                                70
# Senior Data Analyst                                                                           70
# Senior Data Engineer                                                                          57
# Machine Learning Engineer                                                                     55
# Big Data Engineer                                                                             50
# ...

# %%
df['Salary Estimate'].value_counts()
# Out:
# Salary Estimate
# $93K-$151K (Glassdoor est.)         62
# $113K-$180K (Glassdoor est.)        61
# $71K-$122K (Glassdoor est.)         60
# $111K-$175K (Glassdoor est.)        60
# $119K-$147K (Glassdoor est.)        44
# $100K-$172K (Glassdoor est.)        37
# $97K-$159K (Glassdoor est.)         32
# $60K-$124K (Glassdoor est.)         31
# $12K-$111K (Glassdoor est.)         31
# $135K-$214K (Glassdoor est.)        31
# $150K-$169K (Glassdoor est.)        31
# $98K-$152K (Glassdoor est.)         31
# $74K-$144K (Glassdoor est.)         30
# $83K-$154K (Glassdoor est.)         30
# $88K-$140K (Glassdoor est.)         30
# $39K-$69K (Glassdoor est.)          30
# $83K-$165K (Glassdoor est.)         30
# $46K-$82K (Glassdoor est.)          30
# $52K-$94K (Glassdoor est.)          30
# $114K-$146K (Glassdoor est.)        30
# $43K-$76K (Glassdoor est.)          30
# $52K-$91K (Glassdoor est.)          30
# $74K-$140K (Glassdoor est.)         30
# ...

# %%
df['Salary Estimate'] = df['Salary Estimate'].str.replace('$', '')
df['Salary Estimate'] = df['Salary Estimate'].str.replace('K', '')
df['Salary Estimate'] = df['Salary Estimate'].str.replace('(Glassdoor est.)', '')
df['Salary Estimate'] = df['Salary Estimate'].str.replace('(Employer est.)', '')
df['Salary Estimate'] = df['Salary Estimate'].str.replace('Per Hour', '')

# %%
salary = df['Salary Estimate'].str.split('-', expand=True)

df['minimum salary']= salary[0]
df['maximum salary'] =salary[1]

# %%
df.drop('Salary Estimate',axis = 1,inplace = True)

# %%
df.head()
# Out:
#                Job Title                                    Job Description  \
# 0  Senior Data Scientist  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...
# 1         Data Scientist  At Noom, we use scientifically proven methods ...
# 2   Data Science Manager  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...
# 3           Data Analyst  Sapphire Digital seeks a dynamic and driven mi...
# 4               Director  Director, Data Science - (200537)\nDescription...
#
#    Rating                     Company Name       Location      Headquarters  \
# 0     3.5                      Hopper\n3.5   New York, NY  Montreal, Canada
# 1     4.5                     Noom US\n4.5   New York, NY      New York, NY
# 2    -1.0                         Decode_M   New York, NY      New York, NY
# 3     3.4            Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4     3.4  United Entertainment Group\n3.4   New York, NY      New York, NY
#
# ...

# %%
df['minimum salary']= df['minimum salary'].astype(int)
df['maximum salary']= df['maximum salary'].astype(int)

# %%
#df['Job Description'].value_counts()

# %%
df.drop('Job Description',axis = 1,inplace = True)

# %%
df['Rating'].value_counts()
# Out:
# Rating
# -1.0    409
#  3.9    302
#  3.7    290
#  4.1    272
#  3.6    252
#  3.8    238
#  4.0    200
#  3.4    185
#  3.5    176
#  5.0    160
#  4.2    154
#  3.3    154
#  3.2    136
#  4.3    119
#  3.1    113
#  4.5    108
#  4.4     76
#  4.6     74
#  3.0     65
#  2.9     63
#  4.7     59
#  2.8     58
#  4.9     45
#  4.8     42
#  2.5     33
#  2.7     29
#  2.6     27
#  2.4     20
#  2.3     10
#  1.0     10
#  2.2      9
#  1.6      9
#  2.0      4
#  2.1      3
#  1.9      3
#  1.5      1
#  1.7      1
# Name: count, dtype: int64

# %%
df.replace([-1],np.nan,inplace=True)
df.replace(['-1'],np.nan,inplace=True)

# %%
df['Rating'].fillna(0,inplace=True)

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# Apple\n4.1                                                   60
# IBM\n3.7                                                     57
# Amazon\n3.9                                                  47
# Staffigo Technical Services, LLC\n5.0                        28
# Facebook\n4.5                                                25
# Diverse Lynx\n3.9                                            25
# Solekai Systems Corp\n4.2                                    24
# Southwest Research Institute\n4.1                            23
# Varsity Tutors\n4.2                                          21
# Humana\n3.6                                                  20
# GSK\n3.9                                                     18
# CyberCoders\n4.2                                             18
# J&J Family of Companies\n4.0                                 17
# Houston Methodist\n4.1                                       16
# ...

# %%
Company_Name= df['Company Name'].str.split('\n', expand=True)
df['Company Name']= Company_Name[0]

# %%
df['Location'].value_counts()
# Out:
# Location
# Austin, TX                            345
# Chicago, IL                           330
# San Diego, CA                         304
# New York, NY                          303
# Houston, TX                           219
# Philadelphia, PA                      210
# Los Angeles, CA                       206
# Dallas, TX                            180
# San Antonio, TX                       177
# Phoenix, AZ                           165
# Columbus, OH                          152
# Irving, TX                            124
# San Jose, CA                          105
# Jacksonville, FL                       68
# Santa Clara, CA                        65
# Plano, TX                              60
# Tempe, AZ                              49
# Mountain View, CA                      40
# Sunnyvale, CA                          35
# Palo Alto, CA                          33
# Fort Worth, TX                         33
# Scottsdale, AZ                         32
# ...

# %%
location = df['Location'].str.split(',', expand=True)

df['Location city']= location[0]
df['Location state']=location[1]

# %%
df.head()
# Out:
#                Job Title  Rating                Company Name       Location  \
# 0  Senior Data Scientist     3.5                      Hopper   New York, NY
# 1         Data Scientist     4.5                     Noom US   New York, NY
# 2   Data Science Manager     0.0                    Decode_M   New York, NY
# 3           Data Analyst     3.4            Sapphire Digital  Lyndhurst, NJ
# 4               Director     3.4  United Entertainment Group   New York, NY
#
#        Headquarters                    Size  Founded  Type of ownership  \
# 0  Montreal, Canada   501 to 1000 employees   2007.0  Company - Private
# 1      New York, NY  1001 to 5000 employees   2008.0  Company - Private
# 2      New York, NY       1 to 50 employees      NaN            Unknown
# 3     Lyndhurst, NJ    201 to 500 employees   2019.0  Company - Private
# 4      New York, NY     51 to 200 employees   2007.0  Company - Private
#
#                     Industry                  Sector  \
# ...

# %%
df.drop('Location',axis = 1,inplace = True)

# %%
df['Headquarters'].value_counts()
# Out:
# Headquarters
# New York, NY                           297
# San Diego, CA                          179
# Chicago, IL                            158
# Austin, TX                             106
# Los Angeles, CA                         87
# Houston, TX                             83
# San Antonio, TX                         77
# Philadelphia, PA                        67
# Irving, TX                              62
# Armonk, NY                              62
# Columbus, OH                            61
# Cupertino, CA                           60
# Seattle, WA                             60
# Washington, DC                          54
# San Francisco, CA                       52
# Dallas, TX                              51
# San Jose, CA                            50
# Santa Clara, CA                         47
# Saint Louis, MO                         45
# Menlo Park, CA                          41
# London, United Kingdom                  39
# ...

# %%
Headquarters = df['Headquarters'].str.split(',', expand=True)

df['Headquarters_city']= location[0]
df['Headquarters_state']=location[1]

# %%
df['Size'].value_counts()
# Out:
# Size
# 10000+ employees           993
# 51 to 200 employees        563
# 1001 to 5000 employees     553
# 1 to 50 employees          550
# 201 to 500 employees       418
# 501 to 1000 employees      307
# 5001 to 10000 employees    219
# Unknown                     77
# Name: count, dtype: int64

# %%
df.drop('Headquarters',axis = 1,inplace = True)

# %%
df['Size']=df['Size'].replace(['Unknown'],np.nan)
df['Size']=df['Size'].str.replace('employees',"")

# %%
df['Size']=df['Size'].str.replace('+','plus')
df['Size']=df['Size'].str.replace('10000plus','10000 to 10001')

# %%
size=df['Size'].str.split('to',expand=True)
df['minimum size']=size[0]
df['maximum size']=size[1]
df.drop('Size',axis = 1,inplace = True)

# %%
df.head()
# Out:
#                Job Title  Rating                Company Name  Founded  \
# 0  Senior Data Scientist     3.5                      Hopper   2007.0
# 1         Data Scientist     4.5                     Noom US   2008.0
# 2   Data Science Manager     0.0                    Decode_M      NaN
# 3           Data Analyst     3.4            Sapphire Digital   2019.0
# 4               Director     3.4  United Entertainment Group   2007.0
#
#    Type of ownership                   Industry                  Sector  \
# 0  Company - Private            Travel Agencies        Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness       Consumer Services
# 2            Unknown                        NaN                     NaN
# 3  Company - Private                   Internet  Information Technology
# 4  Company - Private    Advertising & Marketing       Business Services
#
#                     Revenue  ... minimum salary maximum salary  Location city  \
# ...

# %%
df['Founded'].unique()
# Out:
# array([2007., 2008.,   nan, 2019., 1985., 1993., 2018., 2000., 2014.,
#        2011., 1999., 2001., 1998., 2005., 1943., 2012., 1923., 2003.,
#        2002., 2015., 2006., 2010., 1853., 1990., 1914., 2013., 2004.,
#        1799., 1935., 1995., 1994., 1988., 1917., 1947., 1981., 1940.,
#        1841., 2017., 1896., 2009., 1898., 1968., 1862., 1934., 1992.,
#        2016., 1984., 1987., 1966., 1976., 1871., 1625., 1997., 1967.,
#        1948., 1913., 1989., 1893., 1904., 1911., 1961., 1806., 1969.,
#        1945., 1784., 1857., 1971., 1852., 1922., 1851., 1956., 1906.,
#        1973., 1960., 1975., 1982., 1996., 1931., 1986., 1902., 1909.,
#        1880., 1946., 1970., 1979., 1977., 1965., 1954., 1850., 1980.,
#        1919., 1983., 1888., 1978., 1872., 1831., 1936., 1939., 1937.,
#        1928., 1991., 1929., 1944., 1901., 1974., 1925., 1817., 1963.,
#        1894., 1890., 1882., 1892., 1908., 1926., 1883., 1845., 1849.,
# ...

# %%
df['Type of ownership'].value_counts()
# Out:
# Type of ownership
# Company - Private                 1933
# Company - Public                  1114
# Nonprofit Organization             207
# Subsidiary or Business Segment     160
# Government                          91
# College / University                77
# Unknown                             38
# Contract                            17
# Hospital                            16
# Private Practice / Firm             12
# School / School District             5
# Other Organization                   5
# Self-employed                        4
# Franchise                            1
# Name: count, dtype: int64

# %%
df['Type of ownership'] = df['Type of ownership'].str.replace('-', '')
ownership =df['Type of ownership'].str.split('/',expand=True)
df['Type of ownership']=ownership[0]

# %%
df['Type of ownership']=df['Type of ownership'].replace('Unknown',np.nan)

# %%
df['Industry'].value_counts()
# Out:
# Industry
# IT Services                                 472
# Staffing & Outsourcing                      313
# Biotech & Pharmaceuticals                   293
# Computer Hardware & Software                264
# Internet                                    238
# Health Care Services & Hospitals            197
# Consulting                                  166
# Enterprise Software & Network Solutions     150
# Investment Banking & Asset Management       109
# Advertising & Marketing                      93
# Insurance Carriers                           91
# Colleges & Universities                      84
# Accounting                                   64
# Banks & Credit Unions                        64
# Research & Development                       60
# Federal Agencies                             57
# Lending                                      41
# Aerospace & Defense                          37
# Video Games                                  30
# ...

# %%
df['Sector'].value_counts()
# Out:
# Sector
# Information Technology                1124
# Business Services                      679
# Biotech & Pharmaceuticals              293
# Finance                                270
# Health Care                            197
# Insurance                              109
# Education                              101
# Manufacturing                           87
# Government                              82
# Media                                   75
# Retail                                  72
# Accounting & Legal                      71
# Aerospace & Defense                     37
# Oil, Gas, Energy & Utilities            34
# Telecommunications                      21
# Consumer Services                       20
# Non-Profit                              18
# Construction, Repair & Maintenance      16
# Transportation & Logistics              16
# Real Estate                             12
# Arts, Entertainment & Recreation        10
# Restaurants, Bars & Food Services        9
# ...

# %%
df['Revenue'].value_counts()
# Out:
# Revenue
# Unknown / Non-Applicable            1163
# $10+ billion (USD)                   599
# $100 to $500 million (USD)           338
# $50 to $100 million (USD)            214
# $2 to $5 billion (USD)               211
# $10 to $25 million (USD)             191
# $1 to $2 billion (USD)               180
# $1 to $5 million (USD)               170
# $25 to $50 million (USD)             143
# $5 to $10 billion (USD)              133
# Less than $1 million (USD)           124
# $500 million to $1 billion (USD)     114
# $5 to $10 million (USD)              100
# Name: count, dtype: int64

# %%
df["Revenue"] = df["Revenue"].replace("Unknown/Non-Applicable",np.nan)
df['Revenue'] = df['Revenue'].str.replace('$', ' ')
df['Revenue'] = df['Revenue'].str.replace('(USD)', ' ')

# %%
df['Revenue'] = df['Revenue'].replace('10+billion', '10billionto11billion')
df['Revenue'] = df['Revenue'].str.replace('million', ' ')
df['Revenue'] = df['Revenue'].str.replace('billion', '000 ')
Revenue = df['Revenue'].str.split("to",expand=True)
df['Min Revenue']=Revenue[0]
df['Max Revenue']=Revenue[1]

# %%
df.head(40)
# Out:
#                                             Job Title  Rating  \
# 0                               Senior Data Scientist     3.5
# 1                                      Data Scientist     4.5
# 2                                Data Science Manager     0.0
# 3                                        Data Analyst     3.4
# 4                                            Director     3.4
# 5                                      Data Scientist     2.9
# 6                             Quantitative Researcher     4.4
# 7                     Quantitative Research Associate     0.0
# 8                                        AI Scientist     5.0
# 9                             Quantitative Researcher     4.8
# 10                                     Data Scientist     3.9
# 11                                     Data Scientist     4.4
# 12                                     Data Scientist     4.3
# 13                                     Data Scientist     3.9
# ...

# %%
df.drop('Revenue',axis=1,inplace=True)

# %%
df['Competitors'].value_counts()
# Out:
# Competitors
# Amazon, Accenture, Microsoft                                                                    61
# Google, Microsoft, Samsung Electronics                                                          60
# Google, Microsoft, Walmart                                                                      47
# Google, Microsoft, Apple                                                                        25
# Los Alamos National Laboratory, Battelle, SRI International                                     23
# Cigna, Aetna, UnitedHealth Group                                                                20
# Pfizer, AstraZeneca, Merck                                                                      18
# Abbott, Novartis, Covidien                                                                      17
# MD Anderson Cancer Center, Memorial Hermann Health System, Texas Children's Hospital            16
# ...

# %%
(df.isna().sum() / len(data)) * 100
# Out:
# Job Title              0.000000
# Rating                 0.000000
# Company Name           0.000000
# Founded               24.993605
# Type of ownership      6.830391
# Industry              13.967767
# Sector                13.967767
# Competitors           70.606293
# Easy Apply            95.804554
# minimum salary         0.000000
# maximum salary         0.000000
# Location city          0.000000
# Location state         0.000000
# Headquarters_city      0.000000
# Headquarters_state     0.000000
# minimum size           7.828089
# maximum size           7.828089
# Min Revenue            5.858276
# Max Revenue           54.105909
# dtype: float64

# %%
df.drop('Competitors',axis=1,inplace=True)

# %%
df['Easy Apply'].value_counts()
# Out:
# Easy Apply
# True    164
# Name: count, dtype: int64

# %%
df['Easy Apply']=df['Easy Apply'].fillna('False')

# %%
df = df.dropna(how='any',axis=0)
df = df.reset_index(drop=True)

# %%
df['Founded']=df['Founded'].astype(int)

# %%
df.head()
# Out:
#         Job Title  Rating        Company Name  Founded Type of ownership  \
# 0  Data Scientist     4.4          PulsePoint     2011  Company  Private
# 1  Data Scientist     4.3  Medidata Solutions     1999   Company  Public
# 2  Data Scientist     3.6                Etsy     2005   Company  Public
# 3  Data Scientist     3.3       PA Consulting     1943  Company  Private
# 4  Data Scientist     3.6                Etsy     2005   Company  Public
#
#                                   Industry                  Sector Easy Apply  \
# 0                                 Internet  Information Technology      False
# 1  Enterprise Software & Network Solutions  Information Technology      False
# 2                      Other Retail Stores                  Retail      False
# 3                               Consulting       Business Services      False
# 4                      Other Retail Stores                  Retail      False
#
# ...
